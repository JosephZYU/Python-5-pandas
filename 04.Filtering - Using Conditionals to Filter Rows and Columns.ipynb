# %%
# 🧭 loc is better for human-readable analysis loc更适用于文本形式分析 -> .loc[row, col] 
# 🧭 If there is ONLY one filter dimension -> use df[filter] directly! 如果只有一个维度的过滤，直接使用df[filter]

import pandas as pd

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

survey_source = '/Users/josephyu/Documents/GitHub/data/survey_results_public.csv'
schema_source = '/Users/josephyu/Documents/GitHub/data/survey_results_schema.csv'

df = pd.read_csv(survey_source, index_col = 'Respondent')
schema_df = pd.read_csv(schema_source, index_col = 'Column')

# %%
df.head(3)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
# 3                             Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# ...

# %%
'United States' in df['Country'].values
# Out:
# True

# %%
df.loc[df['Country']=='United States', 'EdLevel']
# Out:
# Respondent
# 4                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 13             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 22       Some college/university study without earning ...
# 23                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 26       Some college/university study without earning ...
#                                ...
# 78292            Other doctoral degree (Ph.D, Ed.D., etc.)
# 82717    Secondary school (e.g. American high school, G...
# 83397             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 85642                                     Associate degree
# 88282    Some college/university study without earning ...
# Name: EdLevel, Length: 20949, dtype: object

# %%
df['EdLevel'].value_counts()
# Out:
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              39134
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           19569
# Some college/university study without earning a degree                                10502
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     8642
# Associate degree                                                                       2938
# Other doctoral degree (Ph.D, Ed.D., etc.)                                              2432
# Primary/elementary school                                                              1422
# Professional degree (JD, MD, etc.)                                                     1198
# I never completed any formal education                                                  553
# Name: EdLevel, dtype: int64

# %%
filter = (df['EdLevel'] == 'Master’s degree (MA, MS, M.Eng., MBA, etc.)') & (df['Country'] == 'United States')

# %%
df.loc[filter].head(3)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 13                             I am a developer by profession      Yes
# 45          I am not primarily a developer, but I write co...      Yes
# 70                             I am a developer by profession       No
#
#                                                   OpenSourcer  \
# Respondent
# 13          Less than once a month but more than once per ...
# 45                                                      Never
# 70                                    Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 13          OSS is, on average, of HIGHER quality than pro...
# 45          The quality of OSS and closed source software ...
# 70          The quality of OSS and closed source software ...
#
#                     Employment        Country Student  \
# Respondent
# 13          Employed full-time  United States      No
# ...

# %%
filter = (df['EdLevel'] == 'Master’s degree (MA, MS, M.Eng., MBA, etc.)') | (df['Country'] == 'United States')

# %%
df.loc[filter].head(3)
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 4           I am a developer by profession       No
# 10          I am a developer by profession      Yes
# 13          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 4                                                       Never
# 10                                 Once a month or more often
# 13          Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 4           The quality of OSS and closed source software ...
# 10          OSS is, on average, of HIGHER quality than pro...
# 13          OSS is, on average, of HIGHER quality than pro...
#
#                     Employment        Country Student  \
# Respondent
# 4           Employed full-time  United States      No
# 10          Employed full-time          India      No
# ...

# %%
# the opposite of filter ~ tilde
# 🧠 ~filter -> ~

df.loc[~filter].head(3)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
# 3                             Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# ...

# %%
# Filter through people with high-salaries

'Salary' in df.columns
# Out:
# False

# %%
df['ConvertedComp'].value_counts()
# Out:
# 2000000.0    709
# 1000000.0    558
# 120000.0     502
# 100000.0     480
# 150000.0     434
#             ...
# 24156.0        1
# 255720.0       1
# 614.0          1
# 179261.0       1
# 57889.0        1
# Name: ConvertedComp, Length: 9162, dtype: int64

# %%
high_salary = (df['ConvertedComp'] > 70_000)

# %%
df[high_salary]
# Out:
# 88879                                      NaN
# 88882                       MariaDB;PostgreSQL
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 6                                                  PostgreSQL
# 9                                     PostgreSQL;Redis;SQLite
# 13                                       Firebase;MySQL;Redis
# 16          Elasticsearch;MongoDB;Microsoft SQL Server;SQLite
# 22                           Elasticsearch;MySQL;Oracle;Redis
# ...                                                       ...
# 88876                                                DynamoDB
# 88877                                                  Oracle
# 88878                                              PostgreSQL
# 88879                                                     NaN
# 88882                                      MariaDB;PostgreSQL
#
#                                            PlatformWorkedWith  \
# Respondent
# ...
