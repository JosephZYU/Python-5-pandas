# %%
import pandas as pd

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

survey_source = '/Users/josephyu/Documents/GitHub/data/survey_results_public.csv'
schema_source = '/Users/josephyu/Documents/GitHub/data/survey_results_schema.csv'

df = pd.read_csv(survey_source, index_col = 'Respondent')
schema_df = pd.read_csv(schema_source, index_col = 'Column')

# %%
df.head(3)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
# 3                             Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# ...

# %%
df.loc[df['Country'] == 'China', :].head(3)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 56                             I am a developer by profession       No
# 86          I am not primarily a developer, but I write co...      Yes
# 204                    I am a student who is learning to code      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 56                                                      Never
# 86                                 Once a month or more often
# 204         Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 56          The quality of OSS and closed source software ...
# 86          OSS is, on average, of HIGHER quality than pro...
# 204         OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment Country Student  \
# Respondent
# ...

# %%
'China' in df['Country'].values
# Out:
# True
