# %%
import pandas as pd

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

survey_source = '/Users/josephyu/Documents/GitHub/data/survey_results_public.csv'
schema_source = '/Users/josephyu/Documents/GitHub/data/survey_results_schema.csv'

df = pd.read_csv(survey_source, index_col = 'Respondent')
schema_df = pd.read_csv(schema_source, index_col = 'Column')

# %%
# df.sort_values(by='last', ascending=False)

df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
# Sort by column values
# 🧠 df.sort_values(by=[], ascending= ) -> .sort_values(by=[], )

df.sort_values(by='Country', ascending=False).head(3)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 69495       I used to be a developer by profession, but no...       No
# 51356                  I am a student who is learning to code       No
# 6486                   I am a student who is learning to code      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 69495       Less than once a month but more than once per ...
# 51356                                                   Never
# 6486                                                    Never
#
#                                                    OpenSource  \
# Respondent
# 69495       OSS is, on average, of LOWER quality than prop...
# 51356       OSS is, on average, of HIGHER quality than pro...
# 6486        OSS is, on average, of HIGHER quality than pro...
#
#                                                    Employment   Country  \
# Respondent
# ...

# %%
# 🧠 df.sort_values(by=['a', 'b'], ascending=[False, True]) -> .sort_values(by=[], )

df.sort_values(by=['Hobbyist', 'Country'], ascending=[False, True]).head(3)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 6417        I am a student who is learning to code      Yes
# 7085                I am a developer by profession      Yes
# 8149                I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 6417                             Never
# 7085           Less than once per year
# 8149        Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 6417        OSS is, on average, of HIGHER quality than pro...
# 7085        The quality of OSS and closed source software ...
# 8149        OSS is, on average, of LOWER quality than prop...
#
#                                                    Employment      Country  \
# Respondent
# 6417                                       Employed full-time  Afghanistan
# 7085        Independent contractor, freelancer, or self-em...  Afghanistan
# ...

# %%
df.sort_index(ascending=False).head(3)
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 88883       I am a developer by profession      Yes
# 88882       I am a developer by profession      Yes
# 88881       I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 88883       Once a month or more often
# 88882                            Never
# 88881       Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 88883       OSS is, on average, of HIGHER quality than pro...
# 88882       OSS is, on average, of LOWER quality than prop...
# 88881       OSS is, on average, of HIGHER quality than pro...
#
#                     Employment      Country         Student  \
# Respondent
# 88883       Employed full-time       Greece              No
# 88882       Employed full-time  Netherlands  Yes, full-time
# 88881       Employed full-time      Austria              No
#
# ...

# %%
df['ConvertedComp'].sort_values()
# Out:
# Respondent
# 85076    0.0
# 52076    0.0
# 29186    0.0
# 65688    0.0
# 1501     0.0
#         ...
# 88377    NaN
# 88601    NaN
# 88802    NaN
# 88816    NaN
# 88863    NaN
# Name: ConvertedComp, Length: 88883, dtype: float64

# %%
row_filter = df['ConvertedComp'] >= 100_000


high_df = df.loc[row_filter, 'Country':'ConvertedComp'].sort_values(by=['ConvertedComp', 'Country'], ascending=[False, True])

# %%
high_df.shape
# Out:
# (14257, 26)

# %%
row_filter = df['Country'].isin(['China', 'Taiwan', 'Hong Kong (S.A.R.)'])

high_df.loc[row_filter, :]['Country'].value_counts()
# Out:
# Hong Kong (S.A.R.)    18
# China                 15
# Taiwan                 6
# Name: Country, dtype: int64

# %%
high_df['ConvertedComp'].nlargest(710).tail(5) # .value_counts() #.nlargest(100)
# Out:
# Respondent
# 88815    2000000.0
# 88818    2000000.0
# 88874    2000000.0
# 88877    2000000.0
# 4177     1980000.0
# Name: ConvertedComp, dtype: float64

# %%
# Return N-largest (n-largest) results from the entire dataframe
# 🧠 df.nlargest(num, 'Col') -> df.nlargest()

df.nlargest(3, 'ConvertedComp')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 58          I am a developer by profession      Yes
# 102         I am a developer by profession       No
# 166         I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 58          Once a month or more often
# 102                              Never
# 166            Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 58          OSS is, on average, of LOWER quality than prop...
# 102         The quality of OSS and closed source software ...
# 166         The quality of OSS and closed source software ...
#
#                     Employment        Country Student  \
# Respondent
# 58          Employed full-time  United States      No
# 102         Employed full-time  United States      No
# 166         Employed full-time  United States      No
#
#                                              EdLevel  \
# ...

# %%
# Return N-Smallest (n-smallest) results from the entire dataframe
# 🧠 df.nsmallest(num, 'Col') -> df.nsmallest()

df.nsmallest(3, 'ConvertedComp')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 280         I am a developer by profession      Yes
# 293         I am a developer by profession      Yes
# 722         I am a developer by profession       No
#
#                                                   OpenSourcer  \
# Respondent
# 280                                   Less than once per year
# 293                                   Less than once per year
# 722         Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 280         OSS is, on average, of HIGHER quality than pro...
# 293         OSS is, on average, of HIGHER quality than pro...
# 722         The quality of OSS and closed source software ...
#
#                     Employment        Country Student  \
# Respondent
# 280         Employed full-time  United States      No
# 293         Employed full-time    Netherlands      No
# ...
