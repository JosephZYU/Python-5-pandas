# %%
import pandas as pd
import numpy as np

people = {
    "first":['Corey', 'Jane', 'John'],
    "last":['Schafer', 'Doe', 'Smith'],
    "email":['CoreySchafer@gmail.com','JaneDoe@hotmail.com','JohnSmith@outlook.com'],
}


pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', None)  


pd.set_option('display.float_format', lambda x: '%.4f' % x)


survey_source = '/Users/josephyu/Documents/GitHub/data/survey_results_public.csv'
schema_source = '/Users/josephyu/Documents/GitHub/data/survey_results_schema.csv'


df = pd.read_csv(survey_source, index_col = 'Respondent')
schema_df = pd.read_csv(schema_source, index_col = 'Column')
pp_df = pd.DataFrame(people)

# ['Hobbyist', 'OpenSourcer', 'Region'] -> PERFECT Data Quality by column

# %%
df = pp_df

# %%
df = df.applymap(str.strip)

# %%
df['name'] = df['first'] + ' ' + df['last']

# %%
# 🧭 Append can even append to BOTH rows and columns all at once - the ultimate way of adding data as NoSQL style
# Append 可以同时以不定项形式，2维添加行列，非常适合不定项的NoSql模式
# NOTE: BUT 需要确保不任意添加不必要的（重复的）列！ E.g. first == first_name

# 🧠 df.append({dict}, ignore_index=True) -> ignore_index=True

df = df.append({
    'name': 'Adam Smith',
    'first': 'Joseph',
    'last': 'Yu',
    'email': 'JosephYu@gmail.com',
    }, ignore_index=True)

# %%
df
# Out:
#     first     last                   email           name
# 0   Corey  Schafer  CoreySchafer@gmail.com  Corey Schafer
# 1    Jane      Doe     JaneDoe@hotmail.com       Jane Doe
# 2    John    Smith   JohnSmith@outlook.com     John Smith
# 3  Joseph       Yu      JosephYu@gmail.com     Adam Smith

# %%
# df.drop(index=)
# df.drop(columns=)

df.drop(index=2)
# Out:
#     first     last                   email           name
# 0   Corey  Schafer  CoreySchafer@gmail.com  Corey Schafer
# 1    Jane      Doe     JaneDoe@hotmail.com       Jane Doe
# 3  Joseph       Yu      JosephYu@gmail.com     Adam Smith

# %%
filt = df['email'].str.contains('gmail.com')

df.drop(index=df[filt].index,
        columns=['name', 'email'])
# Out:
#   first   last
# 1  Jane    Doe
# 2  John  Smith

# %%
df = pd.read_csv(survey_source, index_col = 'Respondent')

# %%
col_drop = df.isna().mean().sort_values(ascending=False)[:'WebFrameWorkedWith'].index

# %%
tgt_country = df['Country'].value_counts().nsmallest(100)[:'Azerbaijan'].index.tolist()

row_filt = df['Country'].isin(tgt_country)

row_drop = df[row_filt].index

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.drop(
    index=row_drop,
    columns=col_drop,
    inplace=True,
)

# %%
df.sample(3)
# Out:
#                                 MainBranch Hobbyist              OpenSourcer  \
# Respondent
# 29090       I am a developer by profession      Yes  Less than once per year
# 71431       I am a developer by profession      Yes  Less than once per year
# 62029       I am a developer by profession       No                    Never
#
#                                                                                  OpenSource  \
# Respondent
# 29090                       The quality of OSS and closed source software is about the same
# 71431       OSS is, on average, of HIGHER quality than proprietary / closed source software
# 62029                       The quality of OSS and closed source software is about the same
#
#                     Employment        Country Student  \
# Respondent
# 29090       Employed full-time         Israel      No
# 71431       Employed full-time  United States      No
# 62029       Employed full-time    New Zealand      No
#
#                                                            EdLevel  \
# Respondent
# 29090                       I never completed any formal education
# 71431                     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 62029       Some college/university study without earning a degree
#
#                                                              UndergradMajor  \
# Respondent
# 29090                                                                   NaN
# 71431       Computer science, computer engineering, or software engineering
# 62029                                         Web development or web design
#
#                                                                                                                                                                                                                                                                                                        EduOther  \
# Respondent
# 29090                                                                                                         Taken an online course in programming or software development (e.g. a MOOC);Taught yourself a new language, framework, or tool without taking a formal course;Contributed to open source software
# 71431       Taken an online course in programming or software development (e.g. a MOOC);Received on-the-job training in software development;Taught yourself a new language, framework, or tool without taking a formal course;Participated in online coding competitions (e.g. HackerRank, CodeChef, TopCoder)
# 62029                                                                                                                                                                                                                                        Participated in a full-time developer training program or bootcamp
#
#                              OrgSize                     DevType YearsCode  \
# Respondent
# 29090       1,000 to 4,999 employees  Developer, mobile;Educator         4
# 71431           100 to 499 employees       Developer, full-stack        11
# 62029             20 to 99 employees       Developer, full-stack         2
#
#            Age1stCode YearsCodePro              CareerSat  \
# Respondent
# 29090              12            4         Very satisfied
# 71431              16            7  Slightly dissatisfied
# 62029              20            1     Slightly satisfied
#
#                                         JobSat  \
# Respondent
# 29090       Neither satisfied nor dissatisfied
# 71431                        Very dissatisfied
# 62029                       Slightly satisfied
#
#                                                                  JobSeek  \
# Respondent
# 29090       I’m not actively looking, but I am open to new opportunities
# 71431                                    I am actively looking for a job
# 62029       I’m not actively looking, but I am open to new opportunities
#
#                      LastHireDate  \
# Respondent
# 29090               1-2 years ago
# 71431       More than 4 years ago
# 62029               1-2 years ago
#
#                                                                                                                                       LastInt  \
# Respondent
# 29090                                                                                      Interview with people in senior / management roles
# 71431       Write code by hand (e.g., on a whiteboard);Interview with people in peer roles;Interview with people in senior / management roles
# 62029                                                                                      Interview with people in senior / management roles
#
#            FizzBuzz  \
# Respondent
# 29090            No
# 71431            No
# 62029           Yes
#
#                                                                                                                                           JobFactors  \
# Respondent
# 29090       Languages, frameworks, and other technologies I'd be working with;Office environment or company culture;Flex time or a flexible schedule
# 71431                 Specific department or team I'd be working on;Office environment or company culture;Opportunities for professional development
# 62029                              Office environment or company culture;Opportunities for professional development;Flex time or a flexible schedule
#
#                                                       ResumeUpdate  \
# Respondent
# 29090       Something else changed (education, award, media, etc.)
# 71431                             I was preparing for a job search
# 62029             My job status changed (promotion, new job, etc.)
#
#            CurrencySymbol          CurrencyDesc  \
# Respondent
# 29090                 ILS    Israeli new shekel
# 71431                 USD  United States dollar
# 62029                 NZD    New Zealand dollar
#
#                                                                                                 WorkPlan  \
# Respondent
# 29090       There is a schedule and/or spec (made by me or by a colleague), and I follow it very closely
# 71431        There is a schedule and/or spec (made by me or by a colleague), and my work somewhat aligns
# 62029                         There's no schedule or spec; I work on what seems most important or urgent
#
#                                                                                             WorkChallenge  \
# Respondent
# 29090                        Being tasked with non-development work;Distracting work environment;Meetings
# 71431       Being tasked with non-development work;Lack of support from management;Toxic work environment
# 62029                                                                        Distracting work environment
#
#                                   WorkRemote  \
# Respondent
# 29090                  A few days each month
# 71431       Less than once per month / Never
# 62029       Less than once per month / Never
#
#                                                    WorkLoc  \
# Respondent
# 29090       Other place, such as a coworking space or cafe
# 71431                                               Office
# 62029                                               Office
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 29090       A little above average  Yes, because I see value in code review
# 71431       A little above average  Yes, because I see value in code review
# 62029       A little below average                                       No
#
#                          LanguageWorkedWith LanguageDesireNextYear  \
# Respondent
# 29090       HTML/CSS;Java;JavaScript;Kotlin                 Kotlin
# 71431                             C#;Python              C#;Python
# 62029                       Java;JavaScript        JavaScript;Ruby
#
#                       DatabaseWorkedWith DatabaseDesireNextYear  \
# Respondent
# 29090                    Firebase;SQLite        Firebase;SQLite
# 71431       MongoDB;Microsoft SQL Server                    NaN
# 62029                      MongoDB;MySQL                    NaN
#
#               PlatformWorkedWith            PlatformDesireNextYear  \
# Respondent
# 29090                    Android                           Android
# 71431       Docker;Slack;Windows  Docker;Linux;MacOS;Slack;Windows
# 62029                  AWS;Slack                               NaN
#
#                                                DevEnviron    OpSys  \
# Respondent
# 29090           Android Studio;Sublime Text;Visual Studio  Windows
# 71431       Sublime Text;Visual Studio;Visual Studio Code  Windows
# 62029                                                Atom    MacOS
#
#                          Containers BetterLife ITperson  OffOn SocialMedia  \
# Respondent
# 29090       I do not use containers        Yes      Yes  What?    Facebook
# 71431                    Production        Yes     SIGH    Yes     YouTube
# 62029       I do not use containers         No      Yes    Yes   Instagram
#
#                         Extraversion ScreenName SOVisit1st  \
# Respondent
# 29090                         Online   Username       2014
# 71431       In real life (in person)   Username       2013
# 62029       In real life (in person)   Username       2017
#
#                                 SOVisitFreq  \
# Respondent
# 29090                Multiple times per day
# 71431                  A few times per week
# 62029       A few times per month or weekly
#
#                                                                                          SOVisitTo  \
# Respondent
# 29090                                                           Find answers to specific questions
# 71431       Find answers to specific questions;Get a sense of belonging to the developer community
# 62029                                                           Find answers to specific questions
#
#                        SOFindAnswer                         SOTimeSaved  \
# Respondent
# 29090           6-10 times per week  Stack Overflow was slightly faster
# 71431            3-5 times per week  Stack Overflow was slightly faster
# 62029       Less than once per week            They were about the same
#
#             SOHowMuchTime SOAccount                       SOPartFreq  \
# Respondent
# 29090       11-30 minutes       Yes  A few times per month or weekly
# 71431       11-30 minutes       Yes  A few times per month or weekly
# 62029                 NaN        No                              NaN
#
#                                                                                       SOJobs  \
# Respondent
# 29090                                                                                    Yes
# 71431                                                                                    Yes
# 62029       No, I knew that Stack Overflow had a job board but have never used or visited it
#
#                                                                        EntTeams  \
# Respondent
# 29090       No, I've heard of them, but I am not part of a private Q&A instance
# 71431       No, I've heard of them, but I am not part of a private Q&A instance
# 62029                                       No, and I don't know what those are
#
#                      SOComm                             WelcomeChange  \
# Respondent
# 29090       Yes, definitely   Just as welcome now as I felt last year
# 71431         Yes, somewhat   Just as welcome now as I felt last year
# 62029        No, not really  Somewhat more welcome now than last year
#
#                                                                                                                                                                                 SONewContent  \
# Respondent
# 29090       Tech articles written by other developers;Industry news about technologies you're interested in;Tech meetups or events in your area;Courses on technologies you're interested in
# 71431                                                             Tech articles written by other developers;Tech meetups or events in your area;Courses on technologies you're interested in
# 62029                                           Tech articles written by other developers;Industry news about technologies you're interested in;Courses on technologies you're interested in
#
#                Age Gender Trans                Sexuality  \
# Respondent
# 29090      31.0000    Man    No  Straight / Heterosexual
# 71431      28.0000    Man    No                      NaN
# 62029      22.0000    Man    No  Straight / Heterosexual
#
#                                Ethnicity Dependents           SurveyLength  \
# Respondent
# 29090       White or of European descent         No  Appropriate in length
# 71431       White or of European descent         No  Appropriate in length
# 62029       White or of European descent         No  Appropriate in length
#
#                             SurveyEase
# Respondent
# 29090                             Easy
# 71431       Neither easy nor difficult
# 62029                             Easy

# %%
df.sort_values(
    by=['Country', 'Age'],
    ascending=[True, False],
)
# Out:
#                                        ...
# 88062                                                 NaN
# 88076                                                 NaN
# 88601                                                 NaN
# 88802                                                 NaN
# 88816                                                 NaN
#
#                                                       DatabaseWorkedWith  \
# Respondent
# 6206                  Firebase;MongoDB;Microsoft SQL Server;MySQL;SQLite
# 1954                                                               MySQL
# 55906                                                              MySQL
# 6716        MariaDB;MongoDB;Microsoft SQL Server;MySQL;PostgreSQL;SQLite
# 55925                              Elasticsearch;MySQL;Oracle;PostgreSQL
# ...                                                                  ...
# 88062                                                                NaN
# 88076                                                                NaN
# 88601                                                                NaN
# 88802                                                                NaN
# 88816                                                                NaN
#
#                                                   DatabaseDesireNextYear  \
# Respondent
# 6206                                                Microsoft SQL Server
# 1954                           MariaDB;Microsoft SQL Server;MySQL;Oracle
# 55906                                                              MySQL
# 6716        MariaDB;MongoDB;Microsoft SQL Server;MySQL;PostgreSQL;SQLite
# 55925                              Elasticsearch;MySQL;Oracle;PostgreSQL
# ...                                                                  ...
# 88062                                                                NaN
# 88076                                                                NaN
# 88601                                                                NaN
# 88802                                                                NaN
# 88816                                                                NaN
#
#                            PlatformWorkedWith  \
# Respondent
# 6206            Linux;Microsoft Azure;Windows
# 1954                          Linux;WordPress
# 55906                    Docker;Linux;Windows
# 6716        AWS;Linux;Slack;Windows;WordPress
# 55925                     Docker;Heroku;Linux
# ...                                       ...
# 88062                                     NaN
# 88076                                     NaN
# 88601                                     NaN
# 88802                                     NaN
# 88816                                     NaN
#
#                        PlatformDesireNextYear  \
# Respondent
# 6206                  Microsoft Azure;Windows
# 1954                              Android;iOS
# 55906                            Docker;Linux
# 6716        AWS;Linux;Slack;Windows;WordPress
# 55925                                   Linux
# ...                                       ...
# 88062                                     NaN
# 88076                                     NaN
# 88601                                     NaN
# 88802                                     NaN
# 88816                                     NaN
#
#                                                          DevEnviron  \
# Respondent
# 6206                               Visual Studio;Visual Studio Code
# 1954                                                 Notepad++;Zend
# 55906       Atom;Notepad++;PHPStorm;Sublime Text;Visual Studio Code
# 6716              Atom;IntelliJ;Notepad++;PHPStorm;Sublime Text;Vim
# 55925                 Eclipse;IntelliJ;Notepad++;Visual Studio Code
# ...                                                             ...
# 88062                                                           NaN
# 88076                                                           NaN
# 88601                                                           NaN
# 88802                                                           NaN
# 88816                                                           NaN
#
#                   OpSys                      Containers BetterLife  \
# Respondent
# 6206            Windows                     Development        Yes
# 1954            Windows         I do not use containers        Yes
# 55906       Linux-based                     Development         No
# 6716            Windows                     Development        Yes
# 55925           Windows  Development;Testing;Production        Yes
# ...                 ...                             ...        ...
# 88062               NaN                             NaN        NaN
# 88076               NaN                             NaN        NaN
# 88601               NaN                             NaN        NaN
# 88802               NaN                             NaN        NaN
# 88816               NaN                             NaN        NaN
#
#                                             ITperson  OffOn SocialMedia  \
# Respondent
# 6206                                             Yes    Yes    Facebook
# 1954                                             Yes  What?    Facebook
# 55906       Fortunately, someone else has that title    Yes     Twitter
# 6716                                             Yes    Yes    LinkedIn
# 55925                                           SIGH    Yes    WhatsApp
# ...                                              ...    ...         ...
# 88062                                            NaN    NaN         NaN
# 88076                                            NaN    NaN         NaN
# 88601                                            NaN    NaN         NaN
# 88802                                            NaN    NaN         NaN
# 88816                                            NaN    NaN         NaN
#
#                         Extraversion ScreenName SOVisit1st  \
# Respondent
# 6206                          Online   Username       2016
# 1954        In real life (in person)      Login       2009
# 55906       In real life (in person)        NaN       2010
# 6716        In real life (in person)     UserID       2008
# 55925                         Online   Username       2010
# ...                              ...        ...        ...
# 88062                            NaN        NaN        NaN
# 88076                            NaN        NaN        NaN
# 88601                            NaN        NaN        NaN
# 88802                            NaN        NaN        NaN
# 88816                            NaN        NaN        NaN
#
#                                     SOVisitFreq  \
# Respondent
# 6206                      Daily or almost daily
# 1954        Less than once per month or monthly
# 55906           A few times per month or weekly
# 6716                       A few times per week
# 55925                     Daily or almost daily
# ...                                         ...
# 88062                                       NaN
# 88076                                       NaN
# 88601                                       NaN
# 88802                                       NaN
# 88816                                       NaN
#
#                                                                                                                                               SOVisitTo  \
# Respondent
# 6206                                                                                                                 Find answers to specific questions
# 1954                                                                                                                 Find answers to specific questions
# 55906       Find answers to specific questions;Learn how to do things I didn’t necessarily look for;Get a sense of belonging to the developer community
# 6716                                                            Find answers to specific questions;Learn how to do things I didn’t necessarily look for
# 55925                                                                                                                Find answers to specific questions
# ...                                                                                                                                                 ...
# 88062                                                                                                                                               NaN
# 88076                                                                                                                                               NaN
# 88601                                                                                                                                               NaN
# 88802                                                                                                                                               NaN
# 88816                                                                                                                                               NaN
#
#                        SOFindAnswer                         SOTimeSaved  \
# Respondent
# 6206        Less than once per week  Stack Overflow was slightly faster
# 1954        Less than once per week      Stack Overflow was much faster
# 55906            1-2 times per week            They were about the same
# 6716        Less than once per week      Stack Overflow was much faster
# 55925            3-5 times per week      Stack Overflow was much faster
# ...                             ...                                 ...
# 88062                           NaN                                 NaN
# 88076                           NaN                                 NaN
# 88601                           NaN                                 NaN
# 88802                           NaN                                 NaN
# 88816                           NaN                                 NaN
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 6206          60+ minutes       Yes  Less than once per month or monthly
# 1954        31-60 minutes       Yes  Less than once per month or monthly
# 55906                 NaN       Yes  Less than once per month or monthly
# 6716        11-30 minutes       Yes      A few times per month or weekly
# 55925       11-30 minutes       Yes  Less than once per month or monthly
# ...                   ...       ...                                  ...
# 88062                 NaN       NaN                                  NaN
# 88076                 NaN       NaN                                  NaN
# 88601                 NaN       NaN                                  NaN
# 88802                 NaN       NaN                                  NaN
# 88816                 NaN       NaN                                  NaN
#
#                                                                                       SOJobs  \
# Respondent
# 6206                                                                                     Yes
# 1954                                   No, I didn't know that Stack Overflow had a job board
# 55906       No, I knew that Stack Overflow had a job board but have never used or visited it
# 6716                                                                                     Yes
# 55925       No, I knew that Stack Overflow had a job board but have never used or visited it
# ...                                                                                      ...
# 88062                                                                                    NaN
# 88076                                                                                    NaN
# 88601                                                                                    NaN
# 88802                                                                                    NaN
# 88816                                                                                    NaN
#
#                                                                        EntTeams  \
# Respondent
# 6206        No, I've heard of them, but I am not part of a private Q&A instance
# 1954                                        No, and I don't know what those are
# 55906                                       No, and I don't know what those are
# 6716        No, I've heard of them, but I am not part of a private Q&A instance
# 55925                                       No, and I don't know what those are
# ...                                                                         ...
# 88062                                                                       NaN
# 88076                                                                       NaN
# 88601                                                                       NaN
# 88802                                                                       NaN
# 88816                                                                       NaN
#
#                      SOComm                             WelcomeChange  \
# Respondent
# 6206        Yes, definitely  Somewhat more welcome now than last year
# 1954          Yes, somewhat   Just as welcome now as I felt last year
# 55906              Not sure   Just as welcome now as I felt last year
# 6716        Yes, definitely   Just as welcome now as I felt last year
# 55925               Neutral   Just as welcome now as I felt last year
# ...                     ...                                       ...
# 88062                   NaN                                       NaN
# 88076                   NaN                                       NaN
# 88601                   NaN                                       NaN
# 88802                   NaN                                       NaN
# 88816                   NaN                                       NaN
#
#                                                                                                                                                                                 SONewContent  \
# Respondent
# 6206                                                                                                                                               Tech articles written by other developers
# 1954        Tech articles written by other developers;Industry news about technologies you're interested in;Tech meetups or events in your area;Courses on technologies you're interested in
# 55906       Tech articles written by other developers;Industry news about technologies you're interested in;Tech meetups or events in your area;Courses on technologies you're interested in
# 6716                                                              Tech articles written by other developers;Tech meetups or events in your area;Courses on technologies you're interested in
# 55925       Tech articles written by other developers;Industry news about technologies you're interested in;Tech meetups or events in your area;Courses on technologies you're interested in
# ...                                                                                                                                                                                      ...
# 88062                                                                                                                                                                                    NaN
# 88076                                                                                                                                                                                    NaN
# 88601                                                                                                                                                                                    NaN
# 88802                                                                                                                                                                                    NaN
# 88816                                                                                                                                                                                    NaN
#
#                Age Gender Trans                Sexuality  \
# Respondent
# 6206       40.0000    Man    No  Straight / Heterosexual
# 1954       37.0000    Man    No  Straight / Heterosexual
# 55906      37.0000    Man    No  Straight / Heterosexual
# 6716       36.0000    Man    No  Straight / Heterosexual
# 55925      36.0000    Man    No  Straight / Heterosexual
# ...            ...    ...   ...                      ...
# 88062          NaN    NaN   NaN                      NaN
# 88076          NaN    NaN   NaN                      NaN
# 88601          NaN    NaN   NaN                      NaN
# 88802          NaN    NaN   NaN                      NaN
# 88816          NaN    NaN   NaN                      NaN
#
#                                Ethnicity Dependents           SurveyLength  \
# Respondent
# 6206        White or of European descent        Yes               Too long
# 1954        White or of European descent        Yes  Appropriate in length
# 55906       White or of European descent         No               Too long
# 6716        White or of European descent        Yes  Appropriate in length
# 55925       White or of European descent        Yes               Too long
# ...                                  ...        ...                    ...
# 88062                                NaN        NaN                    NaN
# 88076                                NaN        NaN                    NaN
# 88601                                NaN        NaN                    NaN
# 88802                                NaN        NaN                    NaN
# 88816                                NaN        NaN                    NaN
#
#                             SurveyEase
# Respondent
# 6206        Neither easy nor difficult
# 1954                              Easy
# 55906       Neither easy nor difficult
# 6716                              Easy
# 55925       Neither easy nor difficult
# ...                                ...
# 88062                              NaN
# 88076                              NaN
# 88601                              NaN
# 88802                              NaN
# 88816                              NaN
#
# [87794 rows x 67 columns]
